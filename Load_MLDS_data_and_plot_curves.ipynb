# %% [markdown]
# # Load MLDS Responses

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data from the github repository
url = 'https://raw.githubusercontent.com/paudauo/BBDD_Affine_Transformations/refs/heads/main/responses.csv'
df = pd.read_csv(url,header=0, on_bad_lines='skip')
print(df.head(5))
# Out:
#           ref                   dist_ord      resp
# 0  img_01.png  rot_img_01_level_01.png    0.000000
# 1  img_01.png  rot_img_01_level_02.png    0.548906
# 2  img_01.png  rot_img_01_level_03.png    1.041689
# 3  img_01.png  rot_img_01_level_04.png    1.418444
# 4  img_01.png  rot_img_01_level_05.png    2.081331

# %%
# Select the distortion and the image to plot
dist = 'rot' #
img = '01' # '01', '02', ... '24'

exp = dist + '_img_' + img
filtered_df = df[df['dist_ord'].str.startswith(exp)]

# %%
# Plot the MLDS response
# Data is normalized to have standard deviation 1,
# i.e. responses are divided by the standard deviation of the model

plt.errorbar(range(0,10),filtered_df['resp'].values,np.ones(10,))
plt.xlabel('Distortion level')
plt.ylabel('Response')
# Out:
# Text(0, 0.5, 'Response')
