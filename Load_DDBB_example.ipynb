# %% [markdown]
# # Load Raw Data

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/paudauo/BBDD_Affine_Transformations/refs/heads/main/answers.csv'
df = pd.read_csv(url,header=0)
print(df.head(5))
# Out:
#   gender age_group transformation  image_id_01  distortion_level_11  \
# 0    man     41-50          scale           10                    8
# 1    man     41-50          scale           15                   10
# 2    man     41-50          scale           18                    7
# 3    man     41-50          scale            8                    8
# 4    man     41-50          scale           18                    7
#
#    distortion_level_12  distortion_level_21  distortion_level_22  \
# 0                    5                    3                    2
# 1                    6                    3                    2
# 2                    4                    2                    3
# 3                    7                    1                    6
# 4                    6                    3                    1
#
#    reaction_time_ms  answer
# 0              9823       2
# 1              4936       2
# 2             12341       2
# 3              7330       1
# 4              5277       2

# %% [markdown]
# # Load MLDS Responses

# %%
url = 'https://raw.githubusercontent.com/paudauo/BBDD_Affine_Transformations/refs/heads/main/responses.csv'
df = pd.read_csv(url,header=0, on_bad_lines='skip')
print(df.head(5))
# Out:
#           ref                   dist_ord      resp
# 0  img_01.png  rot_img_01_level_01.png    0.000000
# 1  img_01.png  rot_img_01_level_02.png    0.548906
# 2  img_01.png  rot_img_01_level_03.png    1.041689
# 3  img_01.png  rot_img_01_level_04.png    1.418444
# 4  img_01.png  rot_img_01_level_05.png    2.081331
